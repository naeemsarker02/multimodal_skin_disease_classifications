# %% [markdown]
# # Cross-Dataset EDA — Shared Label Comparison (Phase 5, optional/approved addition)
#
# Thin notebook: logic lives in `src/eda/eda_cross_dataset.py`. Compares train-set counts for `disease_label` values shared across 2+ of the 4 datasets.
#
# **This is a class-taxonomy comparison only.** HAM10000, ISIC Archive 1, and ISIC Archive 2 share 40-99% of the same underlying images (`docs/Dataset_Preparation_Final_Report.md` §6) — this chart is not a valid basis for pooling these datasets as independent training data without applying `external_validation_exclusions.csv` first.

# %%
import sys
from pathlib import Path
PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from IPython.display import Image, display
from src.eda import eda_cross_dataset
eda_cross_dataset.main()

# %% [markdown]
# ## Shared labels (9 of 12 total union labels appear in 2+ datasets)
#
# PAD-UFES-20 is the clear outlier in scale for its own frequent classes (Basal Cell Carcinoma, Actinic Keratosis) but contributes far fewer Melanoma/Nevus images than any of the other 3. Vascular Lesion appears only in HAM10000 and ISIC Archive 1 (absent from PAD-UFES-20 and ISIC Archive 2's taxonomies). Pigmented Benign Keratosis appears only in the two ISIC archives (absent from PAD-UFES-20 and HAM10000, which use narrower/different keratosis categories per the label-mapping documentation).

# %%
display(Image(filename="../reports/eda/cross_dataset/figures/01_shared_label_comparison.png"))
